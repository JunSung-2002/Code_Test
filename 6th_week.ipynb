# %% [markdown]
# <a href="https://colab.research.google.com/github/JunSung-2002/Code_Test/blob/Python/6th_week.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 조건문 기본

# %%
age = 25

if age >= 10 and age <20:
    print("청소년입니다. ")
elif age>= 0 and age <10:
    print("영유아입니다.")
elif age>= 20:
    print("성인입니다.")
else:
    print("나이를 잘못 입력하였습니다.") # 나이에 대한 예외처리
# Out:
# 성인입니다.

# %%
print("성별을 대문자 첫번째로 입력해 주세요.")
print("남자는 M, 여자는 F")

sex = input()

if sex == "M":
  print("오른쪽으로 가세요.")
elif sex == "F":
  print("왼쪽으로 가세요.")
else:
  print("성별을 잘못 입력하였습니다")
# Out:
# 성별을 대문자 첫번째로 입력해 주세요.
# 남자는 M, 여자는 F
# F
# 왼쪽으로 가세요.

# %%
print("당신의 주민등록번호 뒷자리 첫번째 숫자를 입력하세요")

sex = int(input())

if sex == 9:
  print("Male")
elif sex == 0:
  print("Female")
else:
  print("다시 확인하여 입력해 주세요.")
# Out:
# 당신의 주민등록번호 뒷자리 첫번째 숫자를 입력하세요
# 0
# Female

# %% [markdown]
# # 정상 혈압 유무 판단

# %% [markdown]
# **정상 혈압 **
#
#
# ![Cap 2021-03-12 03-37-17-371.png](data:image/png;base64,...)

# %% [markdown]
# **딕셔너리 형태로 변수 선언**

# %%
bloodPressure={}

print(bloodPressure)
# Out:
# {}

# %% [markdown]
# **나이 입력 받기**

# %%
print("당신의 나이를 입력하세요")   # 나이 입력
bloodPressure['age'] = int(input())
# Out:
# 당신의 나이를 입력하세요
# 25

# %%
print(bloodPressure)
# Out:
# {'age': 24}

# %%
height={}

print(height)
# Out:
# {}

# %%
print("당신의 키를 입력하세요.")
height['키'] = int(input())
# Out:
# 당신의 키를 입력하세요.
# 167

# %%
print(height)
# Out:
# {'키': 167, '성별': '여성', '최고 몸무게': 42, '최저 몸무게': 39, '나이': 22}

# %% [markdown]
# **성별 입력**

# %%
print("당신의 성별을 입력하세요 : 예: 남성- M, 여성-F")   # 성별 입력
bloodPressure['sex'] = input()
# Out:
# 당신의 성별을 입력하세요 : 예: 남성- M, 여성-F
# M

# %%
print(bloodPressure)
# Out:
# {'age': 25, 'sex': 'M'}

# %%
print("당신의 성별을 입력하세요 : 예: 남성, 여성")   # 성별 입력
height['성별'] = input()
# Out:
# 당신의 성별을 입력하세요 : 예: 남성, 여성
# 여성

# %% [markdown]
# **최고 혈압입력**

# %%
print("최고 혈압을 입력하세요 : ")   # 최고 혈압 입력
bloodPressure['maxBP'] = int(input())
# Out:
# 최고 혈압을 입력하세요 :
# 120

# %%
print("작년 간 최고 몸무게를 입력하세요.")
height['최고 몸무게'] = int(input())
# Out:
# 작년 간 최고 몸무게를 입력하세요.
# 42

# %% [markdown]
# **최저 혈압 입력**

# %%
print("최저 혈압을 입력하세요 : ")   # 최저 혈압 입력
bloodPressure['minBP'] = int(input())
# Out:
# 최저 혈압을 입력하세요 :
# 63

# %%
print("작년 간 최저 몸무게를 입력하세요.")
height['최저 몸무게'] = int(input())
# Out:
# 작년 간 최저 몸무게를 입력하세요.
# 39

# %%
print(bloodPressure)
# Out:
# {'age': 25, 'sex': 'M', 'maxBP': 120, 'minBP': 63}

# %%
print(height)
# Out:
# {'키': 177, '성별': '남성', '최고 몸무게': 92, '최저 몸무게': 83}

# %%
print("현재 나이를 입력하여 주세요.")
height['나이'] = int(input())
# Out:
# 현재 나이를 입력하여 주세요.
# 22

# %%
print(height)
# Out:
# {'키': 167, '성별': '여성', '최고 몸무게': 42, '최저 몸무게': 39, '나이': 22}

# %% [markdown]
# **입력된 데이터 확인**

# %%
print(bloodPressure)
# Out:
# {'age': 25, 'sex': 'M'}

# %% [markdown]
# **정상 혈압 판별**
# (10살 이하 나이에 대해서는 예외처리)

# %%
if (bloodPressure['age'] >= 10 and bloodPressure['age'] < 20):  # 10대
    if(bloodPressure['sex'] == 'M'):
        if(bloodPressure['maxBP']<102 and bloodPressure['minBP']<64):
            print("정상 혈압입니다.")
        else:
            print("비정상 혈압입니다. 정밀 검사가 필요합니다")
    elif (bloodPressure['sex'] == 'F'):
        if(bloodPressure['maxBP']<98 and bloodPressure['minBP']<62):
            print("정상 혈압입니다.")
        else:
            print("비정상 혈압입니다. 정밀 검사가 필요합니다")
    else:
        print("성별을 잘못 입력하였습니다.")    # 성별에 대한 예외 처리

elif (bloodPressure['age'] >= 20  ): # 20대 이상

    if(bloodPressure['sex'] == 'M'):
        if(bloodPressure['maxBP']<120 and bloodPressure['minBP']<80):
            print("정상 혈압입니다.")
        else:
            print("비정상 혈압입니다. 정밀 검사가 필요합니다")
    elif (bloodPressure['sex'] == 'F'):
        if(bloodPressure['maxBP']<115 and bloodPressure['minBP']<75):
            print("정상 혈압입니다.")
        else:
            print("비정상 혈압입니다. 정밀 검사가 필요합니다")
    else:
        print("성별을 잘못 입력하였습니다.")   # 성별에 대한 예외 처리
else:
    print( "나이를 잘못 입력하였습니다.")       # 나이에 대한 예외 처리
# Out:
# 비정상 혈압입니다. 정밀 검사가 필요합니다

# %%
if (height['나이'] >= 10 and height['나이'] <20):
  if(height['성별'] == '남성'):
      if(height['키'] >170):
          if(height['최고 몸무게'] < 90 and height['최저 몸무게'] > 68):
              print("건장합니다.")
          elif(height['최저 몸무게'] >90):
              print("비만 입니다.")
          else:
              print("운동을 하여 건강한 몸을 만드세요.")
      elif(height['키'] <169 and height['키'] >1):
          if(height['최고 몸무게'] <80 and height['최저 몸무게'] >65):
              print("건장합니다")
          elif(height['최저 몸무게'] >80):
              print("비만입니다")
          else:
              print("운동을 하여 체구를 키우세요")
      else:
        print("키를 다시 입력하여 주십시오.")

  elif(height['성별'] == '여성'):
      if(height['키'] >165):
          if(height['최고 몸무게'] <60 and height['최저 몸무게'] >45):
              print("건장합니다.")
          elif(height['최고 몸무게'] <100 and height['최저 몸무게'] >60):
              print("비만입니다.")
          else:
              print("운동을 하여 건강한 몸을 만드세요.")
      elif(height['키'] <165 and height['키'] >1):
          if(height['최고 몸무게'] <50 and height['최저 몸무게'] >40):
              print("건장합니다")
          elif(height['최고 몸무게'] >50):
              print("비만입니다")
          elif(height['최고 몸무게'] <40):
              print("살을 찌우셔야 합니다. 의사랑 상담하세요.")
          else:
              print("운동을 하여 체구를 키우세요")
      else:
        print("키를 다시 입력하여 주십시오.")

elif(height['나이'] >=20 and height['나이'] <30):
  if(height['성별'] == '남성'):
      if(height['키'] >170):
          if(height['최고 몸무게'] <100 and height['최저 몸무게'] >80):
              print("건장합니다.")
          elif(height['최저 몸무게'] >100):
              print("비만 입니다.")
          else:
              print("운동을 하여 건강한 몸을 만드세요.")
      elif(height['키'] <169 and height['키'] >1):
          if(height['최고 몸무게'] <80 and height['최저 몸무게'] >65):
              print("건장합니다")
          elif(height['최고 몸무게'] >100):
              print("비만입니다")
          else:
              print("운동을 하여 체구를 키우세요")
      else:
        print("키를 다시 입력하여 주십시오")
  elif(height['성별'] == '여성'):
      if(height['키'] <200 and height['키'] >165):
          if(height['최고 몸무게'] < 60 and height['최저 몸무게'] > 45):
              print("건장합니다.")
          elif(height['최고 몸무게'] <100 and height['최저 몸무게'] >60):
              print("비만입니다.")
          elif(height['최저 몸무게'] <45):
              print("살을 찌우셔야 합니다. 의사랑 상담하세요.")
      elif(height['키'] <165 and height['키'] >1):
          if(height['최고 몸무게'] <50 and height['최저 몸무게'] >40):
              print("건장합니다")
          elif(height['최고 몸무게'] >50):
              print("비만입니다")
          elif(height['최고 몸무게'] <40):
              print("살을 찌우셔야 합니다. 의사랑 상담하세요.")
      else:
        print("운동을 하여 체구를 키우세요")

else:
  print("30대 미만만 참여할 수 있는 프로그램 입니다.")
# Out:
# 살을 찌우셔야 합니다. 의사랑 상담하세요.
