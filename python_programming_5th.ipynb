# %% [markdown]
# <a href="https://colab.research.google.com/github/JunSung-2002/Code_Test/blob/main/python_programming_5th.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 튜플 자료형

# %% [markdown]
# **튜플 자료형의 정의**

# %%
t1 = ()
t2 = (1,)
t3 = (1, 2, 3)
t4 = 1, 2, 3
t5 = 1, 3, 'oh'
t6 = (9)
t7 = 5
t8 = 6,

print(t1,t2,t3,t4,t5)
print(type(t1))
print(type(t6))
print(type(t7))
print(type(t8))
# Out:
# () (1,) (1, 2, 3) (1, 2, 3) (1, 3, 'oh')
# <class 'tuple'>
# <class 'int'>
# <class 'int'>
# <class 'tuple'>

# %%
t1 = (1,2,'a','b')
t1[3:]

t2 = t1[2:]
t2, t1
# Out:
# (('a', 'b'), (1, 2, 'a', 'b'))

# %% [markdown]
# **튜플 데이터 삭제를 시도한다면?**

# %%
t1 = (1,2,'a','b')
del t1[0]   # 에러 발생!
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-e60ebcde2836> in <module>()
#       1 t1 = (1,2,'a','b')
# ----> 2 del t1[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# **튜플 값에 변경을 시도한다면?**

# %%
t1 = (1,2,'a','b')
t1[0] = 'c'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-54d925f8271e> in <module>()
#       1 t1 = (1,2,'a','b')
# ----> 2 t1[0] = 'c'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# **인덱싱 다루기**

# %%
t1 = (1,2,'a','b')
t1[0]
# Out:
# 1

# %% [markdown]
# **슬라이싱 하기**

# %%
t1 = (1,2,'a','b')
t1[1:]
# Out:
# (2, 'a', 'b')

# %% [markdown]
# **튜플 더하기와 곱하기**

# %%
t2 = (3, 4)
t1+t2
# Out:
# (1, 2, 'a', 'b', 3, 4)

# %% [markdown]
# **튜플 길이 구하기**

# %%
t1 = (1,2,'a','b')
len(t1)
# Out:
# 4

# %% [markdown]
# **튜플을 적용하여 온라인 거래 명세서 만들기**

# %%
transaction1001 = ("파이썬 코딩 길잡이", "데이터베이스론", "JAVA")
print("3월 1일 주문 송장 : ", transaction1001)

transaction1002 = ("요리비법", "영화평론", "헤리포터")
print("3월 15일 주문 송장 : ", transaction1002)
# Out:
# 3월 1일 주문 송장 :  ('파이썬 코딩 길잡이', '데이터베이스론', 'JAVA')
# 3월 15일 주문 송장 :  ('요리비법', '영화평론', '헤리포터')

# %% [markdown]
# # 딕셔너리

# %% [markdown]
# **딕셔너리의 선언**

# %%
dic = {'name':'pey', 'age':'25','birth':'0328'}
print(dic)
a = {1:'hi'}
print(a)
b = {'a':[1,2,3]}
print(b)
# Out:
# {'name': 'pey', 'age': '25', 'birth': '0328'}
# {1: 'hi'}
# {'a': [1, 2, 3]}

# %% [markdown]
# **딕셔너리 쌍 추가하기**

# %%
a = {1: 'a'}
a[2] = 'b'
print(a)

a['name'] = 'pey'
print(a)
# Out:
# {1: 'a', 2: 'b'}
# {1: 'a', 2: 'b', 'name': 'pey'}

# %% [markdown]
# **딕셔너리 key 값이 1인것을 찾아 삭제**

# %%
del a[1]
print(a)
# Out:
# {'a': 'b', 'name': 'pey'}

# %% [markdown]
# **딕셔너리에서 key 를 사용해 value 얻기**

# %%
score = {'pey': 40, 'juliet': 99, 'tom': 70}
print(score['pey'])
print(score['tom'])
# Out:
# 40
# 70

# %% [markdown]
# **딕셔너리 관련 함수**

# %%
a = {'name': 'pey', 'phone': '01022223333', 'birth':'1118'}     # key 만을 모아서 dict_keys 객체로 반환
print(a.keys())

list(a.keys()), list(a.values()), list(a.items())  # key를 모아서 리스트로 변환
# Out:
# dict_keys(['name', 'phone', 'birth'])
# (['name', 'phone', 'birth'],
#  ['pey', '01022223333', '1118'],
#  [('name', 'pey'), ('phone', '01022223333'), ('birth', '1118')])

# %%
a.values()    # value 만을 모아서 dict_value 객체로 반환
# Out:
# dict_values(['pey', '01022223333', '1118'])

# %%
a.items()     # key와 value 쌍을 튜플로 묶은 값을 모아서 idc_items 객체로 반환환
# Out:
# dict_items([('name', 'pey'), ('phone', '01022223333'), ('birth', '1118')])

# %%
a.clear()     # 딕셔너리 요소를 모두 삭제.clear()     # 딕셔너리 요소를 모두 삭제
print(a)
# Out:
# {}

# %% [markdown]
# <strong> key 가 딕셔너리 안에 있는지 조사
# key가 딕셔너리 안에 존재하면 True, 존재하지 않으면 False를 반환 </strong>

# %%
a = {'name': 'pey', 'phone': '01022223333', 'birth':'1118'}

print('name' in a)

print('email' in a)

print('email' not in a)
# Out:
# True
# False
# True

# %% [markdown]
# **key 에 대응되는 value를 반환**

# %%
print(a.get('name'))
print(a.get('phone'))
# Out:
# pey
# 01022223333

# %% [markdown]
# # 집합 자료형

# %% [markdown]
# **집합의 선언**

# %%
s1 = set([1,2,3])
s1
# Out:
# {1, 2, 3}

# %% [markdown]
# **문자열을 입력하여 집합 선언**

# %%
s2 = set("while")
s2
# Out:
# {'e', 'h', 'i', 'l', 'w'}

# %%
t1 = tuple(s1)
t1
t1[2]
# Out:
# 3

# %%
l1 = list(s1)
l1[1]
# Out:
# 2

# %% [markdown]
# **집합 자료형의 연산**

# %%
s1 = set([1, 2, 3, 4, 5, 6])
s2 = set([4, 5, 6, 7, 8, 9])

print(s1 & s2)   # 교집합 s1.intersection(s2) 로도 사용 가능
print(s1 | s2)   # 합집합 s1.union(s2) 로도 사용 가능
print(s1 - s2)   # 차집합 s1.difference(s2) 로도 사용 가능
print(s2 - s1)
# Out:
# {4, 5, 6}
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
# {1, 2, 3}
# {8, 9, 7}

# %% [markdown]
# **집합 관련 함수**

# %%
s1 = set([1, 2, 3])

s1.add(9)     # set 자료형에 요소 추가
print(s1)
s1.remove(2) # set 자료형에 요소 삭제
print(s1)
s1.update([5,6,7,])   # set 자료형에 여러 요소 추가 문자열도 추가 가능
print(s1)
# Out:
# {1, 2, 3, 9}
# {1, 3, 9}
# {1, 3, 5, 6, 7, 9}

# %% [markdown]
# # 불 자료형

# %%
a = True
b = False

print(type(a))
print(type(b))
print(type(s1))
print(type(t1))
# Out:
# <class 'bool'>
# <class 'bool'>
# <class 'set'>
# <class 'tuple'>

# %% [markdown]
# **불 자료형은 데이터가 비어있는 변수에 0을 반환, 값이 있으면 1을 반환함**

# %%
1 == 1 #조건문의 반환값으로도 사용 가능
# Out:
# True

# %%
print(bool("python"))
print(bool(""))
print(bool(1))
print(bool())
# Out:
# True
# False
# True
# False

# %% [markdown]
# # 실습예제

# %% [markdown]
# <strong> **텍스트 데이터 전처리**<br>다양한 데이터 소스로 부터 주소를 받아 표현할때 몇가지의 경우로 서울을 표현하는지 알아보기 </strong>

# %% [markdown]
# 문자열 합치기

# %%
addr1_str="서울시 서울특별시 seoul"
addr2_str="서울 Seoul 서울-특별시"
addr3_str= "서울 서울-시"

# %%
addr_str = addr1_str +" "+ addr2_str + " " + addr3_str

# %%
print(addr_str)   # 합친 문자 확인

addr_str=addr_str.lower()

print(addr_str)
# Out:
# 서울시 서울특별시 seoul 서울 Seoul 서울-특별시 서울 서울-시
# 서울시 서울특별시 seoul 서울 seoul 서울-특별시 서울 서울-시

# %%
addr_list=addr_str.split()
print(addr_list)


print(set(addr_list))   # 중복 문자열 제거

print("서울을 지칭하는 텍스트의 종류 - ",len(addr_list))
# Out:
# ['서울시', '서울특별시', 'seoul', '서울', 'seoul', '서울-특별시', '서울', '서울-시']
# {'서울-특별시', '서울시', '서울특별시', '서울', 'seoul', '서울-시'}
# 서울을 지칭하는 텍스트의 종류 -  8
